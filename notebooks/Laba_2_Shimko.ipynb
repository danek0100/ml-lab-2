# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import os
import math

# %%
pd.set_option("display.max_rows", 1000)

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('train.csv')
val = pd.read_csv('test.csv')

# %%
TARGET_COL = ['SalePrice']

ID_COL = 'Id'

REAL_COLS = ['MSSubClass', 'OverallQual', 'OverallCond', 'LotFrontage', 'LotArea',
             'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
             '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
             'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
             'TotRmsAbvGrd','Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF',
             'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

CAT_COLS = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
            'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
            'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
            'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
            'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
            'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
            'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
            
DATA_COLS = ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'MoSold', 'YrSold']


##for function delete_nan_value
BASEMENT_COLS = ['BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
MASONRY_COLS = ['MasVnrArea']
GARAGE_COLS =['GarageFinish', 'GarageQual', 'GarageCond']
GARAGE_COL = ['GarageYrBlt']

MAX_NUMBER_NAN_VALUE_COLS = ['PoolQC', 'Fence', 'MiscFeature', 'Alley', 'BsmtQual', 'GarageType' , 'FireplaceQu']
NUMBER_OF_TEST = 15

# %%
def preprocess_target(df: pd.DataFrame) -> pd.DataFrame:
    df[TARGET_COL] = df[TARGET_COL].astype(np.int32)
    return df

def extract_target(df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    df, target = df.drop(TARGET_COL, axis = 1), df[TARGET_COL]
    return df, target

def cast_types(df: pd.DataFrame) -> pd.DataFrame:
    df[CAT_COLS] = df[CAT_COLS].astype('category')
    df[REAL_COLS] = df[REAL_COLS].astype(np.int32)
    df[DATA_COLS] = df[DATA_COLS].astype(np.int32)
    return df

def set_idx(df: pd.DataFrame, idx_col: str) -> pd.DataFrame:
    df = df.set_index(idx_col)
    return df

# %%
def delete_nan_value(df: pd.DataFrame) ->pd.DataFrame:
    ##basement 
    for col in BASEMENT_COLS:
        temp_array = list(df[col])
        count = 0
        for index, row in df.iterrows():
            if row['BsmtQual'] == 'NA':
                if pd.isna(row[col]):
                    temp_array[count] = 'NA'
            count += 1
        df = df.drop(columns = col)
        count = 0
        for index, row in df.iterrows():
            df.loc[index,col] = temp_array[count]
            count += 1 
        df = df[(pd.isna(df[col])) == False] 
    
    ##Masonry veneer
    for col in MASONRY_COLS:
        temp_array = list(df[col])
        count = 0
        for index, row in df.iterrows():
            if row['MasVnrType'] == 'None':
                if pd.isna(row[col]):
                    temp_array[count] = 0
            count += 1
        df = df.drop(columns = col)
        count = 0
        for index, row in df.iterrows():
            df.loc[index,col] = temp_array[count]
            count += 1 
        df = df[(pd.isna(df[col])) == False] 
    
    ##Electrical 
    df = df[(pd.isna(df['Electrical'])) == False] 

    ##Garage
    for col in GARAGE_COLS:
        temp_array = list(df[col])
        count = 0
        for index, row in df.iterrows():
            if row['GarageType'] == 'NA':
                if pd.isna(row[col]):
                    temp_array[count] = 'NA'
            count += 1
        df = df.drop(columns = col)
        count = 0
        for index, row in df.iterrows():
            df.loc[index,col] = temp_array[count]
            count += 1 
        df = df[(pd.isna(df[col])) == False] 
    for col in GARAGE_COL:
        temp_array = list(df[col])
        count = 0
        for index, row in df.iterrows():
            if row['GarageType'] == 'NA':
                if pd.isna(row[col]):
                    temp_array[count] = 0
            count += 1
        df = df.drop(columns = col)
        count = 0
        for index, row in df.iterrows():
            df.loc[index,col] = temp_array[count]
            count += 1 
        df = df[(pd.isna(df[col])) == False]            
    return df

# %%
def full_columns_with_max_number_of_nan(df: pd.DataFrame) -> pd.DataFrame:
    df[MAX_NUMBER_NAN_VALUE_COLS] = df[MAX_NUMBER_NAN_VALUE_COLS].replace(np.nan, 'NA')
    df['LotFrontage'] = df['LotFrontage'].replace(np.nan, 0) 
    df['MasVnrType'] = df['MasVnrType'].replace(np.nan, 'None')

    return df

# %%
def preprocess_df(df: pd.DataFrame) -> pd.DataFrame:
    df = set_idx(df, ID_COL)
    df = full_columns_with_max_number_of_nan(df)
    df = delete_nan_value(df)
    df = cast_types(df)
    return df

# %%
def preprocess_val(df: pd.DataFrame) -> pd.DataFrame:
    df = set_idx(df, ID_COL)
    df = full_columns_with_max_number_of_nan(df)
    df = delete_nan_value(df)
    df = df.apply(lambda x: x.fillna(x.value_counts().index[0]))
    df = cast_types(df)
    return df

# %%
import pickle
from typing import Union
from pandas import DataFrame
from pandas.core.indexes.base import Index as PandasIndex


def save_as_pickle(obj: Union[DataFrame, PandasIndex], path: str) -> None:
    if isinstance(obj, DataFrame):
        obj.to_pickle(path)
    elif isinstance(obj, PandasIndex):
        with open('path', 'wb') as f:
            pickle.dump(obj, f)

# %%
df = preprocess_df(df)
val = preprocess_val(val)

##только для train()
df, target = extract_target(df)
target = preprocess_target(target)
#save_as_pickle(target, '../data/processed/target_for_data_for_train.pkl')
#save_as_pickle(df, '../data/interim/data_for_train.pkl')

##только для val
#save_as_pickle(val, '../data/interim/val.pkl')

# %% [markdown]
# # Feature generation

# %%
# interim_data_path = '../data/interim/'
# train = pd.read_pickle(os.path.join(interim_data_path, 'data_for_train.pkl'))
# test = pd.read_pickle(os.path.join(interim_data_path, 'val.pkl'))

# %%
train = df
test = val

# %%
##for feature generation  class of building

def LotFrontage_points(lotfrontage_) -> int:
    if lotfrontage_ >= 100:
        return 5
    elif 40 <= lotfrontage_ < 100:
        return 4
    elif 30 <= lotfrontage_ < 40:
        return 3
    elif 0 < lotfrontage_ < 30:
        return 2 
    else:
        return 0

def LotArea_points(lotarea_) -> int:
    if lotarea_ >= 16000:
        return 5
    elif 9000 <= lotarea_ < 16000:
        return 4
    elif 5000 <= lotarea_ < 9000:
        return 3
    elif 0 < lotarea_ < 5000:
        return 2
    else:
        return 0

def Utilities_points(utilities_) -> int:
    if utilities_ == 'AllPub':
        return 5
    elif utilities_ == 'NoSewr':
        return 4
    elif utilities_ == 'NoSeWa':
        return 3
    elif utilities_ == 'ELO':
        return 2 
    else:
        return 0

def OverallQual_points(overallqual_) -> int:
    excellent = [10, 9, 8]
    good = [7, 6]
    average = [5, 4]
    poor = [3, 2, 1]
    if overallqual_ in excellent:
        return 5
    elif overallqual_ in good:
        return 4
    elif overallqual_ in average:
        return 3
    elif overallqual_ in poor:
        return 2
    else:
        return 0

def OverallCond_points(overallcond_) -> int:
    excellent = [10, 9, 8]
    good = [7, 6]
    average = [5, 4]
    poor = [3, 2, 1]
    if overallcond_ in excellent:
        return 5
    elif overallcond_ in good:
        return 4
    elif overallcond_ in average:
        return 3
    elif overallcond_ in poor:
        return 2
    else:
        return 0

def YearBuilt_points(yearbuilt_) -> int:
    if yearbuilt_ >= 2000:
        return 5
    elif 1971 <= yearbuilt_ < 2000:
        return 4
    elif 1920 <= yearbuilt_ < 1971:
        return 3
    elif yearbuilt_ < 1920:
        return 2
    else:
        return 0

def BsmtFinType1_points(bsmtfintype1_) -> int:
    if bsmtfintype1_ == 'GLQ' or bsmtfintype1_ == 'ALQ':
        return 5
    elif bsmtfintype1_ == 'BLQ' or bsmtfintype1_ == 'Rec':
        return 4
    elif bsmtfintype1_ == 'LwQ':
        return 3
    elif bsmtfintype1_ == 'Unf':
        return 2 
    else:
        return 0

def BsmtFinType2_points(bsmtfintype2_) -> int:
    if bsmtfintype2_ == 'GLQ' or bsmtfintype2_ == 'ALQ':
        return 5
    elif bsmtfintype2_ == 'BLQ' or bsmtfintype2_ == 'Rec':
        return 4
    elif bsmtfintype2_ == 'LwQ':
        return 3
    elif bsmtfintype2_ == 'Unf':
        return 2 
    else:
        return 0

def TotalBsmtSF_points(totalbsmtsf_) -> int:
    if totalbsmtsf_ >= 3000:
        return 5
    elif 1000 <= totalbsmtsf_ < 3000:
        return 4
    elif 500 <= totalbsmtsf_ < 1000:
        return 3
    elif 0 < totalbsmtsf_ < 500:
        return 2
    else:
        return 0

def TotRmsAbvGrd_points(totrmsabvgrd_) -> int:
    if totrmsabvgrd_ >= 10:
        return 5
    elif 6 <= totrmsabvgrd_ < 10:
        return 4
    elif 3 <= totrmsabvgrd_ < 6:
        return 3
    elif totrmsabvgrd_ < 3:
        return 2
    else:
        return 0

def GarageType_points(garagetype_) -> int:
    if garagetype_ == '2Types' or garagetype_ == 'Attchd':
        return 5
    elif garagetype_ == 'Basment' or garagetype_ == 'BuiltIn':
        return 4
    elif garagetype_ == 'CarPort':
        return 3
    elif garagetype_ == 'Detchd':
        return 2 
    else:
        return 0

def GarageYrBlt_points(garageyrblt_) -> int:
    if garageyrblt_ >= 2000:
        return 5
    elif 1971 <= garageyrblt_ < 2000:
        return 4
    elif 1920 <= garageyrblt_ < 1971:
        return 3
    elif garageyrblt_ < 1920:
        return 2
    else:
        return 0

def GarageArea_points(garagearea_) -> int:
    if garagearea_ >= 900:
        return 5
    elif 400 <= garagearea_ < 900:
        return 4
    elif 200 <= garagearea_ < 400:
        return 3
    elif 0 < garagearea_ < 200:
        return 2
    else:
        return 0

def PoolArea_points(poolarea_) -> int:
    if poolarea_ >= 100:
        return 5
    elif 50 <= poolarea_ < 100:
        return 4
    elif 2 <= poolarea_ < 50:
        return 3
    elif 0 < poolarea_ < 2:
        return 2
    else:
        return 0

def MiscFeature_points(miscfeature_) -> int:
    if miscfeature_ != 'NA':
        return 5
    else:
        return 0

# %%
def class_of_building(df: pd.DataFrame) -> pd.DataFrame:
    building_class = []
    for index, row in df.iterrows():
        count = 0
        count += LotFrontage_points(row['LotFrontage'])
        count += LotArea_points(row['LotArea'])
        count += Utilities_points(row['Utilities'])
        count += OverallQual_points(row['OverallQual'])
        count += OverallCond_points(row['OverallCond'])
        count += YearBuilt_points(row['YearBuilt'])
        count += BsmtFinType1_points(row['BsmtFinType1'])
        count += BsmtFinType2_points(row['BsmtFinType2'])
        count += TotalBsmtSF_points(row['TotalBsmtSF'])
        count += TotRmsAbvGrd_points(row['TotRmsAbvGrd'])
        count += GarageType_points(row['GarageType'])
        count += GarageYrBlt_points(row['GarageYrBlt'])
        count += GarageArea_points(row['GarageArea'])
        count += PoolArea_points(row['PoolArea'])
        count += MiscFeature_points(row['MiscFeature']) 
        building_class.append(round( count/NUMBER_OF_TEST))
    i = 0 
    for index, row in df.iterrows():
            df.loc[index,'ClassBuilt'] = building_class[i]
            i += 1 
    df['ClassBuilt'] = df['ClassBuilt'].astype(np.int32)
    return df

# %%
## age at the sold moment 
def age_of_building_at_the_time_of_sale(df: pd.DataFrame) -> pd.DataFrame:
    building_age = []
    for index, row in df.iterrows():
        building_age.append(int(row['YrSold'] - row['YearBuilt']))
    i = 0 
    for index, row in df.iterrows():
            df.loc[index,'BuiltAge'] = building_age[i]
            i += 1 
    df['BuiltAge'] = df['BuiltAge'].astype(np.int32)
    return df

# %%
def feature_generation(df: pd.DataFrame) -> pd.DataFrame:
    df = class_of_building(df)
    df = age_of_building_at_the_time_of_sale(df)
    return df

# %%
train = feature_generation(train)
test = feature_generation(test)

# save_as_pickle(test, '../data/processed/test.pkl')
# save_as_pickle(train, '../data/processed/data_for_train.pkl')

# %% [markdown]
# # Modeling

# %%
import os
import pandas as pd
import numpy as np

from sklearn.svm import *
from sklearn.model_selection import *
from sklearn.preprocessing import *
from sklearn.compose import *
from sklearn.pipeline import *
from sklearn.metrics import *
from sklearn.impute import *
from sklearn.multioutput import *
from sklearn.metrics import precision_score, f1_score, recall_score, roc_auc_score

#%pip install catboost
import catboost
from catboost import Pool,cv
from catboost import CatBoostClassifier, CatBoostRegressor

import skmultilearn
from skmultilearn.model_selection import IterativeStratification

#%pip install category_encoders
import category_encoders as ce
#%pip install lightgbm
import lightgbm as ltb

# %% [markdown]
# ## Training

# %%
# processed_data_path = '../data/processed/'
# train = pd.read_pickle(os.path.join(processed_data_path, 'data_for_train.pkl'))
# target = pd.read_pickle(os.path.join(processed_data_path, 'target_for_data_for_train.pkl'))

# %%
train_ = train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(train_, target, test_size=0.3, random_state=77)

# %%
# from sklearn.model_selection import GridSearchCV

# model_ = CatBoostRegressor(cat_features = CAT_COLS)
# parameters = {
#     'iterations': [100,150,300,500,1000,1100], 
#     'loss_function':['RMSE', 'MAPE', 'MAE'],
#     'learning_rate' : [0.01, 0.1, 0.02, 0.3],
#     'ctr_leaf_count_limit': [5, 10, 20, 30]
#     }
# clf = GridSearchCV(model_, parameters)
# clf.fit(X_train, Y_train)

# %%
##CATBOOST
model = CatBoostRegressor(
    iterations = 1000,
    loss_function='MAPE',
    cat_features = CAT_COLS)


pipeline_castboost = Pipeline ([
    ('model_cast', model)])

pipeline_castboost.fit(X_train,Y_train)
# Out:
# c:\Users\dsfs-\AppData\Local\Programs\Python\Python39\lib\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# 0:	learn: 0.2827555	total: 64.3ms	remaining: 1m 4s
# 1:	learn: 0.2803795	total: 131ms	remaining: 1m 5s
# 2:	learn: 0.2781094	total: 224ms	remaining: 1m 14s
# 3:	learn: 0.2772690	total: 298ms	remaining: 1m 14s
# 4:	learn: 0.2756719	total: 364ms	remaining: 1m 12s
# 5:	learn: 0.2737766	total: 427ms	remaining: 1m 10s
# 6:	learn: 0.2727841	total: 493ms	remaining: 1m 9s
# 7:	learn: 0.2708255	total: 564ms	remaining: 1m 9s
# 8:	learn: 0.2702294	total: 638ms	remaining: 1m 10s
# 9:	learn: 0.2690027	total: 695ms	remaining: 1m 8s
# 10:	learn: 0.2676575	total: 763ms	remaining: 1m 8s
# 11:	learn: 0.2667437	total: 834ms	remaining: 1m 8s
# 12:	learn: 0.2666251	total: 864ms	remaining: 1m 5s
# 13:	learn: 0.2663087	total: 924ms	remaining: 1m 5s
# 14:	learn: 0.2645759	total: 988ms	remaining: 1m 4s
# 15:	learn: 0.2632008	total: 1.06s	remaining: 1m 5s
# 16:	learn: 0.2617398	total: 1.14s	remaining: 1m 5s
# 17:	learn: 0.2612499	total: 1.21s	remaining: 1m 5s
# 18:	learn: 0.2601923	total: 1.26s	remaining: 1m 4s
# 19:	learn: 0.2591212	total: 1.32s	remaining: 1m 4s
# 20:	learn: 0.2585910	total: 1.39s	remaining: 1m 4s
# 21:	learn: 0.2583714	total: 1.44s	remaining: 1m 3s
# 22:	learn: 0.2572752	total: 1.49s	remaining: 1m 3s
# 23:	learn: 0.2566091	total: 1.54s	remaining: 1m 2s
# 24:	learn: 0.2557608	total: 1.61s	remaining: 1m 2s
# 25:	learn: 0.2551405	total: 1.68s	remaining: 1m 2s
# 26:	learn: 0.2542597	total: 1.74s	remaining: 1m 2s
# 27:	learn: 0.2533777	total: 1.81s	remaining: 1m 2s
# 28:	learn: 0.2524317	total: 1.88s	remaining: 1m 2s
# 29:	learn: 0.2517748	total: 1.94s	remaining: 1m 2s
# 30:	learn: 0.2511944	total: 2s	remaining: 1m 2s
# 31:	learn: 0.2507848	total: 2.07s	remaining: 1m 2s
# 32:	learn: 0.2505151	total: 2.13s	remaining: 1m 2s
# 33:	learn: 0.2500014	total: 2.18s	remaining: 1m 1s
# 34:	learn: 0.2495493	total: 2.23s	remaining: 1m 1s
# 35:	learn: 0.2488195	total: 2.29s	remaining: 1m 1s
# 36:	learn: 0.2482711	total: 2.35s	remaining: 1m 1s
# 37:	learn: 0.2477397	total: 2.4s	remaining: 1m
# 38:	learn: 0.2476913	total: 2.43s	remaining: 59.9s
# 39:	learn: 0.2474179	total: 2.48s	remaining: 59.5s
# 40:	learn: 0.2468484	total: 2.53s	remaining: 59.1s
# 41:	learn: 0.2465026	total: 2.59s	remaining: 59s
# 42:	learn: 0.2460014	total: 2.64s	remaining: 58.8s
# 43:	learn: 0.2456368	total: 2.7s	remaining: 58.7s
# 44:	learn: 0.2450421	total: 2.75s	remaining: 58.5s
# 45:	learn: 0.2441419	total: 2.81s	remaining: 58.3s
# 46:	learn: 0.2432427	total: 2.87s	remaining: 58.1s
# 47:	learn: 0.2430884	total: 2.92s	remaining: 57.8s
# 48:	learn: 0.2424552	total: 2.97s	remaining: 57.7s
# 49:	learn: 0.2415542	total: 3.02s	remaining: 57.5s
# 50:	learn: 0.2407159	total: 3.07s	remaining: 57.2s
# 51:	learn: 0.2398531	total: 3.12s	remaining: 56.9s
# 52:	learn: 0.2388632	total: 3.17s	remaining: 56.6s
# 53:	learn: 0.2382171	total: 3.22s	remaining: 56.5s
# 54:	learn: 0.2376624	total: 3.28s	remaining: 56.3s
# 55:	learn: 0.2374821	total: 3.33s	remaining: 56.1s
# 56:	learn: 0.2371005	total: 3.38s	remaining: 55.9s
# 57:	learn: 0.2369905	total: 3.43s	remaining: 55.7s
# 58:	learn: 0.2365592	total: 3.48s	remaining: 55.5s
# 59:	learn: 0.2362316	total: 3.53s	remaining: 55.3s
# 60:	learn: 0.2360331	total: 3.58s	remaining: 55.1s
# 61:	learn: 0.2354996	total: 3.63s	remaining: 54.9s
# 62:	learn: 0.2352794	total: 3.68s	remaining: 54.7s
# 63:	learn: 0.2352690	total: 3.72s	remaining: 54.5s
# 64:	learn: 0.2346649	total: 3.77s	remaining: 54.3s
# 65:	learn: 0.2342478	total: 3.83s	remaining: 54.2s
# 66:	learn: 0.2338330	total: 3.88s	remaining: 54s
# 67:	learn: 0.2329722	total: 3.93s	remaining: 53.8s
# 68:	learn: 0.2327414	total: 3.98s	remaining: 53.7s
# 69:	learn: 0.2323995	total: 4.04s	remaining: 53.6s
# 70:	learn: 0.2315247	total: 4.08s	remaining: 53.4s
# 71:	learn: 0.2313980	total: 4.13s	remaining: 53.3s
# 72:	learn: 0.2306314	total: 4.18s	remaining: 53.1s
# 73:	learn: 0.2299859	total: 4.24s	remaining: 53.1s
# 74:	learn: 0.2296470	total: 4.29s	remaining: 53s
# 75:	learn: 0.2293100	total: 4.34s	remaining: 52.8s
# 76:	learn: 0.2288621	total: 4.39s	remaining: 52.7s
# 77:	learn: 0.2288305	total: 4.43s	remaining: 52.4s
# 78:	learn: 0.2285136	total: 4.48s	remaining: 52.3s
# 79:	learn: 0.2282741	total: 4.53s	remaining: 52.1s
# 80:	learn: 0.2278795	total: 4.58s	remaining: 52s
# 81:	learn: 0.2275504	total: 4.64s	remaining: 51.9s
# 82:	learn: 0.2266277	total: 4.69s	remaining: 51.8s
# 83:	learn: 0.2260031	total: 4.74s	remaining: 51.7s
# 84:	learn: 0.2259651	total: 4.79s	remaining: 51.5s
# 85:	learn: 0.2255463	total: 4.84s	remaining: 51.4s
# 86:	learn: 0.2253453	total: 4.89s	remaining: 51.3s
# 87:	learn: 0.2251520	total: 4.95s	remaining: 51.3s
# 88:	learn: 0.2251465	total: 4.98s	remaining: 50.9s
# 89:	learn: 0.2245749	total: 5.02s	remaining: 50.8s
# 90:	learn: 0.2240605	total: 5.08s	remaining: 50.7s
# 91:	learn: 0.2238254	total: 5.13s	remaining: 50.6s
# 92:	learn: 0.2236458	total: 5.18s	remaining: 50.5s
# 93:	learn: 0.2232181	total: 5.24s	remaining: 50.5s
# 94:	learn: 0.2215973	total: 5.29s	remaining: 50.4s
# 95:	learn: 0.2212224	total: 5.34s	remaining: 50.3s
# 96:	learn: 0.2208715	total: 5.39s	remaining: 50.2s
# 97:	learn: 0.2206635	total: 5.44s	remaining: 50.1s
# 98:	learn: 0.2204296	total: 5.49s	remaining: 50s
# 99:	learn: 0.2200828	total: 5.54s	remaining: 49.9s
# 100:	learn: 0.2197027	total: 5.6s	remaining: 49.8s
# 101:	learn: 0.2192432	total: 5.64s	remaining: 49.7s
# 102:	learn: 0.2191456	total: 5.7s	remaining: 49.7s
# 103:	learn: 0.2190865	total: 5.76s	remaining: 49.7s
# 104:	learn: 0.2187250	total: 5.87s	remaining: 50s
# 105:	learn: 0.2185840	total: 5.97s	remaining: 50.4s
# 106:	learn: 0.2180982	total: 6.04s	remaining: 50.5s
# 107:	learn: 0.2176592	total: 6.1s	remaining: 50.4s
# 108:	learn: 0.2175014	total: 6.15s	remaining: 50.3s
# 109:	learn: 0.2170671	total: 6.2s	remaining: 50.2s
# 110:	learn: 0.2162749	total: 6.26s	remaining: 50.1s
# 111:	learn: 0.2157178	total: 6.31s	remaining: 50s
# 112:	learn: 0.2155860	total: 6.37s	remaining: 50s
# 113:	learn: 0.2151400	total: 6.42s	remaining: 49.9s
# 114:	learn: 0.2147121	total: 6.48s	remaining: 49.8s
# 115:	learn: 0.2143976	total: 6.53s	remaining: 49.7s
# 116:	learn: 0.2141191	total: 6.58s	remaining: 49.6s
# 117:	learn: 0.2137908	total: 6.63s	remaining: 49.5s
# 118:	learn: 0.2136603	total: 6.68s	remaining: 49.5s
# 119:	learn: 0.2132126	total: 6.74s	remaining: 49.4s
# 120:	learn: 0.2127936	total: 6.79s	remaining: 49.3s
# 121:	learn: 0.2115969	total: 6.84s	remaining: 49.2s
# 122:	learn: 0.2115914	total: 6.86s	remaining: 48.9s
# 123:	learn: 0.2114430	total: 6.91s	remaining: 48.8s
# 124:	learn: 0.2109566	total: 6.97s	remaining: 48.8s
# 125:	learn: 0.2105851	total: 7.02s	remaining: 48.7s
# 126:	learn: 0.2103048	total: 7.08s	remaining: 48.6s
# 127:	learn: 0.2099352	total: 7.14s	remaining: 48.6s
# 128:	learn: 0.2097669	total: 7.19s	remaining: 48.6s
# 129:	learn: 0.2097568	total: 7.24s	remaining: 48.4s
# 130:	learn: 0.2096428	total: 7.29s	remaining: 48.4s
# 131:	learn: 0.2095139	total: 7.35s	remaining: 48.3s
# 132:	learn: 0.2088798	total: 7.41s	remaining: 48.3s
# 133:	learn: 0.2084165	total: 7.47s	remaining: 48.3s
# 134:	learn: 0.2081165	total: 7.52s	remaining: 48.2s
# 135:	learn: 0.2076642	total: 7.57s	remaining: 48.1s
# 136:	learn: 0.2073697	total: 7.63s	remaining: 48s
# 137:	learn: 0.2068553	total: 7.69s	remaining: 48.1s
# 138:	learn: 0.2064772	total: 7.75s	remaining: 48s
# 139:	learn: 0.2064517	total: 7.83s	remaining: 48.1s
# 140:	learn: 0.2062028	total: 7.92s	remaining: 48.2s
# 141:	learn: 0.2057798	total: 8s	remaining: 48.3s
# 142:	learn: 0.2057090	total: 8.08s	remaining: 48.4s
# 143:	learn: 0.2052781	total: 8.16s	remaining: 48.5s
# 144:	learn: 0.2048823	total: 8.24s	remaining: 48.6s
# 145:	learn: 0.2046231	total: 8.3s	remaining: 48.6s
# 146:	learn: 0.2038889	total: 8.36s	remaining: 48.5s
# 147:	learn: 0.2036241	total: 8.41s	remaining: 48.4s
# 148:	learn: 0.2032224	total: 8.47s	remaining: 48.4s
# 149:	learn: 0.2028699	total: 8.53s	remaining: 48.3s
# 150:	learn: 0.2027766	total: 8.58s	remaining: 48.2s
# 151:	learn: 0.2026895	total: 8.63s	remaining: 48.1s
# 152:	learn: 0.2023846	total: 8.68s	remaining: 48s
# 153:	learn: 0.2021713	total: 8.73s	remaining: 48s
# 154:	learn: 0.2019307	total: 8.78s	remaining: 47.9s
# 155:	learn: 0.2017123	total: 8.83s	remaining: 47.8s
# 156:	learn: 0.2014871	total: 8.88s	remaining: 47.7s
# 157:	learn: 0.2013581	total: 8.94s	remaining: 47.6s
# 158:	learn: 0.2011783	total: 8.99s	remaining: 47.5s
# 159:	learn: 0.2011783	total: 9.01s	remaining: 47.3s
# 160:	learn: 0.2009394	total: 9.06s	remaining: 47.2s
# 161:	learn: 0.2001969	total: 9.11s	remaining: 47.1s
# 162:	learn: 0.1997011	total: 9.17s	remaining: 47.1s
# 163:	learn: 0.1994126	total: 9.22s	remaining: 47s
# 164:	learn: 0.1993305	total: 9.27s	remaining: 46.9s
# 165:	learn: 0.1987813	total: 9.33s	remaining: 46.9s
# 166:	learn: 0.1987069	total: 9.38s	remaining: 46.8s
# 167:	learn: 0.1985011	total: 9.44s	remaining: 46.7s
# 168:	learn: 0.1984333	total: 9.49s	remaining: 46.7s
# 169:	learn: 0.1981785	total: 9.54s	remaining: 46.6s
# 170:	learn: 0.1978426	total: 9.6s	remaining: 46.5s
# 171:	learn: 0.1977025	total: 9.65s	remaining: 46.5s
# 172:	learn: 0.1973598	total: 9.71s	remaining: 46.4s
# 173:	learn: 0.1969462	total: 9.76s	remaining: 46.3s
# 174:	learn: 0.1967183	total: 9.82s	remaining: 46.3s
# 175:	learn: 0.1965986	total: 9.86s	remaining: 46.2s
# 176:	learn: 0.1963527	total: 9.92s	remaining: 46.1s
# 177:	learn: 0.1958288	total: 9.99s	remaining: 46.1s
# 178:	learn: 0.1955716	total: 10.1s	remaining: 46.1s
# 179:	learn: 0.1953328	total: 10.1s	remaining: 46.1s
# 180:	learn: 0.1952917	total: 10.2s	remaining: 45.9s
# 181:	learn: 0.1951409	total: 10.2s	remaining: 45.9s
# 182:	learn: 0.1950388	total: 10.3s	remaining: 45.8s
# 183:	learn: 0.1946788	total: 10.3s	remaining: 45.7s
# 184:	learn: 0.1944606	total: 10.4s	remaining: 45.7s
# 185:	learn: 0.1942339	total: 10.4s	remaining: 45.6s
# 186:	learn: 0.1940610	total: 10.5s	remaining: 45.5s
# 187:	learn: 0.1937631	total: 10.5s	remaining: 45.5s
# 188:	learn: 0.1936176	total: 10.6s	remaining: 45.4s
# 189:	learn: 0.1935629	total: 10.6s	remaining: 45.4s
# 190:	learn: 0.1932628	total: 10.7s	remaining: 45.3s
# 191:	learn: 0.1930203	total: 10.8s	remaining: 45.2s
# 192:	learn: 0.1929628	total: 10.8s	remaining: 45.2s
# 193:	learn: 0.1925703	total: 10.9s	remaining: 45.1s
# 194:	learn: 0.1924023	total: 10.9s	remaining: 45.2s
# 195:	learn: 0.1920599	total: 11s	remaining: 45.2s
# 196:	learn: 0.1917844	total: 11.1s	remaining: 45.3s
# 197:	learn: 0.1916004	total: 11.2s	remaining: 45.3s
# 198:	learn: 0.1911821	total: 11.3s	remaining: 45.3s
# 199:	learn: 0.1909847	total: 11.3s	remaining: 45.3s
# 200:	learn: 0.1907457	total: 11.4s	remaining: 45.3s
# 201:	learn: 0.1904342	total: 11.5s	remaining: 45.4s
# 202:	learn: 0.1899614	total: 11.6s	remaining: 45.4s
# 203:	learn: 0.1896888	total: 11.6s	remaining: 45.4s
# 204:	learn: 0.1896082	total: 11.7s	remaining: 45.3s
# 205:	learn: 0.1896083	total: 11.7s	remaining: 45.2s
# 206:	learn: 0.1894366	total: 11.8s	remaining: 45.1s
# 207:	learn: 0.1891976	total: 11.8s	remaining: 45s
# 208:	learn: 0.1889043	total: 11.9s	remaining: 45s
# 209:	learn: 0.1887587	total: 11.9s	remaining: 44.9s
# 210:	learn: 0.1884651	total: 12s	remaining: 44.8s
# 211:	learn: 0.1882540	total: 12s	remaining: 44.8s
# 212:	learn: 0.1881615	total: 12.1s	remaining: 44.9s
# 213:	learn: 0.1878730	total: 12.2s	remaining: 44.8s
# 214:	learn: 0.1874996	total: 12.3s	remaining: 44.9s
# 215:	learn: 0.1873186	total: 12.4s	remaining: 44.9s
# 216:	learn: 0.1870870	total: 12.4s	remaining: 44.8s
# 217:	learn: 0.1868390	total: 12.5s	remaining: 44.8s
# 218:	learn: 0.1868040	total: 12.5s	remaining: 44.7s
# 219:	learn: 0.1866782	total: 12.6s	remaining: 44.8s
# 220:	learn: 0.1863671	total: 12.7s	remaining: 44.8s
# 221:	learn: 0.1861449	total: 12.8s	remaining: 44.8s
# 222:	learn: 0.1858184	total: 12.9s	remaining: 44.8s
# 223:	learn: 0.1856614	total: 13s	remaining: 44.9s
# 224:	learn: 0.1853453	total: 13s	remaining: 44.9s
# 225:	learn: 0.1852185	total: 13.1s	remaining: 44.9s
# 226:	learn: 0.1852071	total: 13.2s	remaining: 44.9s
# 227:	learn: 0.1850296	total: 13.2s	remaining: 44.8s
# 228:	learn: 0.1849669	total: 13.3s	remaining: 44.8s
# 229:	learn: 0.1848875	total: 13.4s	remaining: 44.9s
# 230:	learn: 0.1848116	total: 13.5s	remaining: 44.8s
# 231:	learn: 0.1847181	total: 13.5s	remaining: 44.8s
# 232:	learn: 0.1845079	total: 13.6s	remaining: 44.8s
# 233:	learn: 0.1843632	total: 13.6s	remaining: 44.7s
# 234:	learn: 0.1842653	total: 13.7s	remaining: 44.6s
# 235:	learn: 0.1841801	total: 13.7s	remaining: 44.5s
# 236:	learn: 0.1841799	total: 13.8s	remaining: 44.4s
# 237:	learn: 0.1839430	total: 13.8s	remaining: 44.3s
# 238:	learn: 0.1838393	total: 13.9s	remaining: 44.2s
# 239:	learn: 0.1836771	total: 13.9s	remaining: 44.2s
# 240:	learn: 0.1835594	total: 14s	remaining: 44.1s
# 241:	learn: 0.1833395	total: 14.1s	remaining: 44s
# 242:	learn: 0.1831692	total: 14.1s	remaining: 44s
# 243:	learn: 0.1828673	total: 14.2s	remaining: 43.9s
# 244:	learn: 0.1827706	total: 14.2s	remaining: 43.8s
# 245:	learn: 0.1826231	total: 14.3s	remaining: 43.7s
# 246:	learn: 0.1823200	total: 14.3s	remaining: 43.7s
# 247:	learn: 0.1820508	total: 14.4s	remaining: 43.6s
# 248:	learn: 0.1819451	total: 14.5s	remaining: 43.6s
# 249:	learn: 0.1816477	total: 14.5s	remaining: 43.5s
# 250:	learn: 0.1814286	total: 14.6s	remaining: 43.4s
# 251:	learn: 0.1810745	total: 14.6s	remaining: 43.4s
# 252:	learn: 0.1808948	total: 14.7s	remaining: 43.3s
# 253:	learn: 0.1808425	total: 14.7s	remaining: 43.2s
# 254:	learn: 0.1806665	total: 14.8s	remaining: 43.1s
# 255:	learn: 0.1804625	total: 14.8s	remaining: 43.1s
# 256:	learn: 0.1803071	total: 14.9s	remaining: 43s
# 257:	learn: 0.1800133	total: 14.9s	remaining: 42.9s
# 258:	learn: 0.1798525	total: 15s	remaining: 42.9s
# 259:	learn: 0.1797355	total: 15s	remaining: 42.8s
# 260:	learn: 0.1795608	total: 15.1s	remaining: 42.7s
# 261:	learn: 0.1794289	total: 15.1s	remaining: 42.6s
# 262:	learn: 0.1793316	total: 15.2s	remaining: 42.5s
# 263:	learn: 0.1791355	total: 15.2s	remaining: 42.4s
# 264:	learn: 0.1788575	total: 15.3s	remaining: 42.4s
# 265:	learn: 0.1786447	total: 15.3s	remaining: 42.3s
# 266:	learn: 0.1781273	total: 15.4s	remaining: 42.2s
# 267:	learn: 0.1779603	total: 15.4s	remaining: 42.1s
# 268:	learn: 0.1777960	total: 15.5s	remaining: 42.1s
# 269:	learn: 0.1775928	total: 15.5s	remaining: 42s
# 270:	learn: 0.1774668	total: 15.6s	remaining: 41.9s
# 271:	learn: 0.1772582	total: 15.6s	remaining: 41.9s
# 272:	learn: 0.1770819	total: 15.7s	remaining: 41.8s
# 273:	learn: 0.1770056	total: 15.7s	remaining: 41.7s
# 274:	learn: 0.1767956	total: 15.8s	remaining: 41.7s
# 275:	learn: 0.1766018	total: 15.9s	remaining: 41.6s
# 276:	learn: 0.1764945	total: 15.9s	remaining: 41.5s
# 277:	learn: 0.1763398	total: 16s	remaining: 41.4s
# 278:	learn: 0.1762483	total: 16s	remaining: 41.4s
# 279:	learn: 0.1761150	total: 16.1s	remaining: 41.3s
# 280:	learn: 0.1759474	total: 16.1s	remaining: 41.2s
# 281:	learn: 0.1758478	total: 16.2s	remaining: 41.1s
# 282:	learn: 0.1757550	total: 16.2s	remaining: 41.1s
# 283:	learn: 0.1756485	total: 16.3s	remaining: 41s
# 284:	learn: 0.1755310	total: 16.3s	remaining: 40.9s
# 285:	learn: 0.1752993	total: 16.4s	remaining: 40.8s
# 286:	learn: 0.1751693	total: 16.4s	remaining: 40.8s
# 287:	learn: 0.1749524	total: 16.5s	remaining: 40.7s
# 288:	learn: 0.1747916	total: 16.5s	remaining: 40.6s
# 289:	learn: 0.1746409	total: 16.6s	remaining: 40.5s
# 290:	learn: 0.1745580	total: 16.6s	remaining: 40.5s
# 291:	learn: 0.1742386	total: 16.7s	remaining: 40.4s
# 292:	learn: 0.1741038	total: 16.7s	remaining: 40.3s
# 293:	learn: 0.1738178	total: 16.8s	remaining: 40.3s
# 294:	learn: 0.1735696	total: 16.8s	remaining: 40.2s
# 295:	learn: 0.1733669	total: 16.9s	remaining: 40.1s
# 296:	learn: 0.1731822	total: 16.9s	remaining: 40s
# 297:	learn: 0.1730977	total: 17s	remaining: 40s
# 298:	learn: 0.1728990	total: 17s	remaining: 39.9s
# 299:	learn: 0.1727634	total: 17.1s	remaining: 39.8s
# 300:	learn: 0.1726587	total: 17.1s	remaining: 39.8s
# 301:	learn: 0.1726143	total: 17.2s	remaining: 39.7s
# 302:	learn: 0.1723865	total: 17.2s	remaining: 39.6s
# 303:	learn: 0.1722931	total: 17.3s	remaining: 39.5s
# 304:	learn: 0.1721301	total: 17.3s	remaining: 39.4s
# 305:	learn: 0.1720090	total: 17.4s	remaining: 39.4s
# 306:	learn: 0.1717941	total: 17.4s	remaining: 39.3s
# 307:	learn: 0.1715475	total: 17.5s	remaining: 39.2s
# 308:	learn: 0.1714078	total: 17.5s	remaining: 39.1s
# 309:	learn: 0.1709946	total: 17.5s	remaining: 39.1s
# 310:	learn: 0.1708474	total: 17.6s	remaining: 39s
# 311:	learn: 0.1707691	total: 17.6s	remaining: 38.9s
# 312:	learn: 0.1706104	total: 17.7s	remaining: 38.8s
# 313:	learn: 0.1704526	total: 17.7s	remaining: 38.7s
# 314:	learn: 0.1702149	total: 17.8s	remaining: 38.7s
# 315:	learn: 0.1700869	total: 17.8s	remaining: 38.6s
# 316:	learn: 0.1699582	total: 17.9s	remaining: 38.5s
# 317:	learn: 0.1697955	total: 17.9s	remaining: 38.5s
# 318:	learn: 0.1697346	total: 18s	remaining: 38.4s
# 319:	learn: 0.1696037	total: 18s	remaining: 38.3s
# 320:	learn: 0.1694875	total: 18.1s	remaining: 38.3s
# 321:	learn: 0.1694490	total: 18.1s	remaining: 38.2s
# 322:	learn: 0.1693566	total: 18.2s	remaining: 38.1s
# 323:	learn: 0.1692385	total: 18.2s	remaining: 38s
# 324:	learn: 0.1691254	total: 18.3s	remaining: 38s
# 325:	learn: 0.1690410	total: 18.3s	remaining: 37.9s
# 326:	learn: 0.1689340	total: 18.4s	remaining: 37.8s
# 327:	learn: 0.1685597	total: 18.4s	remaining: 37.7s
# 328:	learn: 0.1682148	total: 18.5s	remaining: 37.7s
# 329:	learn: 0.1681380	total: 18.5s	remaining: 37.6s
# 330:	learn: 0.1680508	total: 18.6s	remaining: 37.5s
# 331:	learn: 0.1679781	total: 18.6s	remaining: 37.4s
# 332:	learn: 0.1679220	total: 18.7s	remaining: 37.4s
# 333:	learn: 0.1678191	total: 18.7s	remaining: 37.3s
# 334:	learn: 0.1677268	total: 18.8s	remaining: 37.2s
# 335:	learn: 0.1675868	total: 18.8s	remaining: 37.2s
# 336:	learn: 0.1675130	total: 18.9s	remaining: 37.1s
# 337:	learn: 0.1674812	total: 18.9s	remaining: 37s
# 338:	learn: 0.1673626	total: 19s	remaining: 37s
# 339:	learn: 0.1672533	total: 19s	remaining: 36.9s
# 340:	learn: 0.1672064	total: 19.1s	remaining: 36.8s
# 341:	learn: 0.1669652	total: 19.1s	remaining: 36.8s
# 342:	learn: 0.1669149	total: 19.2s	remaining: 36.8s
# 343:	learn: 0.1668672	total: 19.3s	remaining: 36.8s
# 344:	learn: 0.1667710	total: 19.4s	remaining: 36.8s
# 345:	learn: 0.1666827	total: 19.5s	remaining: 36.8s
# 346:	learn: 0.1665756	total: 19.5s	remaining: 36.7s
# 347:	learn: 0.1662902	total: 19.6s	remaining: 36.7s
# 348:	learn: 0.1661974	total: 19.6s	remaining: 36.6s
# 349:	learn: 0.1659986	total: 19.7s	remaining: 36.6s
# 350:	learn: 0.1659153	total: 19.7s	remaining: 36.5s
# 351:	learn: 0.1657532	total: 19.8s	remaining: 36.5s
# 352:	learn: 0.1656814	total: 19.9s	remaining: 36.4s
# 353:	learn: 0.1655457	total: 20s	remaining: 36.5s
# 354:	learn: 0.1653317	total: 20s	remaining: 36.4s
# 355:	learn: 0.1652675	total: 20.1s	remaining: 36.4s
# 356:	learn: 0.1651543	total: 20.2s	remaining: 36.3s
# 357:	learn: 0.1650005	total: 20.2s	remaining: 36.3s
# 358:	learn: 0.1648994	total: 20.3s	remaining: 36.2s
# 359:	learn: 0.1647558	total: 20.3s	remaining: 36.1s
# 360:	learn: 0.1644144	total: 20.4s	remaining: 36.1s
# 361:	learn: 0.1640458	total: 20.4s	remaining: 36s
# 362:	learn: 0.1639538	total: 20.5s	remaining: 35.9s
# 363:	learn: 0.1637843	total: 20.5s	remaining: 35.9s
# 364:	learn: 0.1636130	total: 20.6s	remaining: 35.8s
# 365:	learn: 0.1634538	total: 20.6s	remaining: 35.7s
# 366:	learn: 0.1633841	total: 20.7s	remaining: 35.7s
# 367:	learn: 0.1631732	total: 20.8s	remaining: 35.6s
# 368:	learn: 0.1629522	total: 20.8s	remaining: 35.6s
# 369:	learn: 0.1628439	total: 20.9s	remaining: 35.5s
# 370:	learn: 0.1624475	total: 20.9s	remaining: 35.5s
# 371:	learn: 0.1623288	total: 21s	remaining: 35.4s
# 372:	learn: 0.1619754	total: 21s	remaining: 35.4s
# 373:	learn: 0.1619308	total: 21.1s	remaining: 35.3s
# 374:	learn: 0.1618486	total: 21.1s	remaining: 35.3s
# 375:	learn: 0.1617028	total: 21.2s	remaining: 35.2s
# 376:	learn: 0.1615936	total: 21.3s	remaining: 35.1s
# 377:	learn: 0.1615406	total: 21.3s	remaining: 35s
# 378:	learn: 0.1614711	total: 21.3s	remaining: 35s
# 379:	learn: 0.1614268	total: 21.4s	remaining: 34.9s
# 380:	learn: 0.1611782	total: 21.4s	remaining: 34.8s
# 381:	learn: 0.1609330	total: 21.5s	remaining: 34.8s
# 382:	learn: 0.1608861	total: 21.5s	remaining: 34.7s
# 383:	learn: 0.1607746	total: 21.6s	remaining: 34.6s
# 384:	learn: 0.1607333	total: 21.6s	remaining: 34.6s
# 385:	learn: 0.1606603	total: 21.7s	remaining: 34.5s
# 386:	learn: 0.1606175	total: 21.8s	remaining: 34.5s
# 387:	learn: 0.1604280	total: 21.8s	remaining: 34.4s
# 388:	learn: 0.1603626	total: 21.9s	remaining: 34.3s
# 389:	learn: 0.1602819	total: 21.9s	remaining: 34.3s
# 390:	learn: 0.1602026	total: 22s	remaining: 34.2s
# 391:	learn: 0.1601047	total: 22s	remaining: 34.1s
# 392:	learn: 0.1600759	total: 22.1s	remaining: 34.1s
# 393:	learn: 0.1600254	total: 22.1s	remaining: 34s
# 394:	learn: 0.1599035	total: 22.2s	remaining: 33.9s
# 395:	learn: 0.1598305	total: 22.2s	remaining: 33.9s
# 396:	learn: 0.1597712	total: 22.3s	remaining: 33.8s
# 397:	learn: 0.1597269	total: 22.3s	remaining: 33.8s
# 398:	learn: 0.1596650	total: 22.4s	remaining: 33.7s
# 399:	learn: 0.1595480	total: 22.4s	remaining: 33.7s
# 400:	learn: 0.1594797	total: 22.5s	remaining: 33.6s
# 401:	learn: 0.1594257	total: 22.6s	remaining: 33.6s
# 402:	learn: 0.1593494	total: 22.6s	remaining: 33.5s
# 403:	learn: 0.1592663	total: 22.7s	remaining: 33.5s
# 404:	learn: 0.1592196	total: 22.8s	remaining: 33.4s
# 405:	learn: 0.1591282	total: 22.8s	remaining: 33.4s
# 406:	learn: 0.1590177	total: 22.9s	remaining: 33.4s
# 407:	learn: 0.1589828	total: 23s	remaining: 33.3s
# 408:	learn: 0.1588431	total: 23s	remaining: 33.3s
# 409:	learn: 0.1587495	total: 23.1s	remaining: 33.2s
# 410:	learn: 0.1586411	total: 23.1s	remaining: 33.2s
# 411:	learn: 0.1585296	total: 23.2s	remaining: 33.1s
# 412:	learn: 0.1584892	total: 23.2s	remaining: 33s
# 413:	learn: 0.1584600	total: 23.3s	remaining: 33s
# 414:	learn: 0.1582972	total: 23.3s	remaining: 32.9s
# 415:	learn: 0.1582020	total: 23.4s	remaining: 32.8s
# 416:	learn: 0.1579998	total: 23.4s	remaining: 32.8s
# 417:	learn: 0.1579316	total: 23.5s	remaining: 32.7s
# 418:	learn: 0.1579005	total: 23.5s	remaining: 32.6s
# 419:	learn: 0.1576233	total: 23.6s	remaining: 32.6s
# 420:	learn: 0.1575560	total: 23.7s	remaining: 32.5s
# 421:	learn: 0.1575262	total: 23.7s	remaining: 32.5s
# 422:	learn: 0.1574815	total: 23.8s	remaining: 32.4s
# 423:	learn: 0.1574032	total: 23.8s	remaining: 32.3s
# 424:	learn: 0.1572109	total: 23.9s	remaining: 32.3s
# 425:	learn: 0.1571397	total: 23.9s	remaining: 32.2s
# 426:	learn: 0.1570603	total: 24s	remaining: 32.1s
# 427:	learn: 0.1570114	total: 24s	remaining: 32.1s
# 428:	learn: 0.1568602	total: 24s	remaining: 32s
# 429:	learn: 0.1568157	total: 24.1s	remaining: 31.9s
# 430:	learn: 0.1566629	total: 24.1s	remaining: 31.9s
# 431:	learn: 0.1565761	total: 24.2s	remaining: 31.8s
# 432:	learn: 0.1564593	total: 24.2s	remaining: 31.7s
# 433:	learn: 0.1563967	total: 24.3s	remaining: 31.7s
# 434:	learn: 0.1563097	total: 24.3s	remaining: 31.6s
# 435:	learn: 0.1562137	total: 24.4s	remaining: 31.6s
# 436:	learn: 0.1561770	total: 24.4s	remaining: 31.5s
# 437:	learn: 0.1561465	total: 24.5s	remaining: 31.4s
# 438:	learn: 0.1560965	total: 24.5s	remaining: 31.4s
# 439:	learn: 0.1559350	total: 24.6s	remaining: 31.3s
# 440:	learn: 0.1558974	total: 24.6s	remaining: 31.2s
# 441:	learn: 0.1557194	total: 24.7s	remaining: 31.2s
# 442:	learn: 0.1556745	total: 24.7s	remaining: 31.1s
# 443:	learn: 0.1555984	total: 24.8s	remaining: 31s
# 444:	learn: 0.1553675	total: 24.8s	remaining: 31s
# 445:	learn: 0.1552563	total: 24.9s	remaining: 30.9s
# 446:	learn: 0.1551447	total: 24.9s	remaining: 30.8s
# 447:	learn: 0.1549948	total: 25s	remaining: 30.8s
# 448:	learn: 0.1549356	total: 25s	remaining: 30.7s
# 449:	learn: 0.1548642	total: 25.1s	remaining: 30.6s
# 450:	learn: 0.1547019	total: 25.1s	remaining: 30.6s
# 451:	learn: 0.1546642	total: 25.1s	remaining: 30.5s
# 452:	learn: 0.1543941	total: 25.2s	remaining: 30.4s
# 453:	learn: 0.1543590	total: 25.2s	remaining: 30.4s
# 454:	learn: 0.1543286	total: 25.3s	remaining: 30.3s
# 455:	learn: 0.1542474	total: 25.3s	remaining: 30.2s
# 456:	learn: 0.1541847	total: 25.4s	remaining: 30.2s
# 457:	learn: 0.1540491	total: 25.4s	remaining: 30.1s
# 458:	learn: 0.1539879	total: 25.5s	remaining: 30s
# 459:	learn: 0.1539403	total: 25.5s	remaining: 30s
# 460:	learn: 0.1537895	total: 25.6s	remaining: 29.9s
# 461:	learn: 0.1537315	total: 25.6s	remaining: 29.8s
# 462:	learn: 0.1536734	total: 25.7s	remaining: 29.8s
# 463:	learn: 0.1534416	total: 25.7s	remaining: 29.7s
# 464:	learn: 0.1534009	total: 25.8s	remaining: 29.7s
# 465:	learn: 0.1533208	total: 25.8s	remaining: 29.6s
# 466:	learn: 0.1532079	total: 25.9s	remaining: 29.5s
# 467:	learn: 0.1531516	total: 25.9s	remaining: 29.5s
# 468:	learn: 0.1529006	total: 26s	remaining: 29.4s
# 469:	learn: 0.1528535	total: 26s	remaining: 29.3s
# 470:	learn: 0.1527492	total: 26.1s	remaining: 29.3s
# 471:	learn: 0.1526878	total: 26.1s	remaining: 29.2s
# 472:	learn: 0.1526275	total: 26.2s	remaining: 29.1s
# 473:	learn: 0.1524975	total: 26.2s	remaining: 29.1s
# 474:	learn: 0.1524291	total: 26.3s	remaining: 29.1s
# 475:	learn: 0.1523961	total: 26.4s	remaining: 29s
# 476:	learn: 0.1523833	total: 26.4s	remaining: 29s
# 477:	learn: 0.1523480	total: 26.6s	remaining: 29s
# 478:	learn: 0.1521596	total: 26.6s	remaining: 29s
# 479:	learn: 0.1521001	total: 26.7s	remaining: 28.9s
# 480:	learn: 0.1520239	total: 26.8s	remaining: 28.9s
# 481:	learn: 0.1519813	total: 26.9s	remaining: 28.9s
# 482:	learn: 0.1518298	total: 26.9s	remaining: 28.8s
# 483:	learn: 0.1517470	total: 27s	remaining: 28.8s
# 484:	learn: 0.1517103	total: 27.1s	remaining: 28.7s
# 485:	learn: 0.1516971	total: 27.1s	remaining: 28.7s
# 486:	learn: 0.1516130	total: 27.2s	remaining: 28.6s
# 487:	learn: 0.1512266	total: 27.2s	remaining: 28.6s
# 488:	learn: 0.1511887	total: 27.4s	remaining: 28.6s
# 489:	learn: 0.1507890	total: 27.5s	remaining: 28.6s
# 490:	learn: 0.1507109	total: 27.6s	remaining: 28.6s
# 491:	learn: 0.1506506	total: 27.7s	remaining: 28.6s
# 492:	learn: 0.1506071	total: 27.7s	remaining: 28.5s
# 493:	learn: 0.1505617	total: 27.8s	remaining: 28.4s
# 494:	learn: 0.1505269	total: 27.9s	remaining: 28.4s
# 495:	learn: 0.1504200	total: 28s	remaining: 28.4s
# 496:	learn: 0.1503879	total: 28s	remaining: 28.4s
# 497:	learn: 0.1503197	total: 28.1s	remaining: 28.3s
# 498:	learn: 0.1502778	total: 28.1s	remaining: 28.2s
# 499:	learn: 0.1502288	total: 28.2s	remaining: 28.2s
# 500:	learn: 0.1501502	total: 28.2s	remaining: 28.1s
# 501:	learn: 0.1501097	total: 28.3s	remaining: 28.1s
# 502:	learn: 0.1500798	total: 28.3s	remaining: 28s
# 503:	learn: 0.1500134	total: 28.4s	remaining: 27.9s
# 504:	learn: 0.1498479	total: 28.5s	remaining: 27.9s
# 505:	learn: 0.1497941	total: 28.5s	remaining: 27.8s
# 506:	learn: 0.1497296	total: 28.6s	remaining: 27.8s
# 507:	learn: 0.1494919	total: 28.6s	remaining: 27.7s
# 508:	learn: 0.1493663	total: 28.7s	remaining: 27.6s
# 509:	learn: 0.1493330	total: 28.7s	remaining: 27.6s
# 510:	learn: 0.1492527	total: 28.8s	remaining: 27.5s
# 511:	learn: 0.1491901	total: 28.8s	remaining: 27.5s
# 512:	learn: 0.1491405	total: 28.9s	remaining: 27.4s
# 513:	learn: 0.1489960	total: 28.9s	remaining: 27.4s
# 514:	learn: 0.1487675	total: 29s	remaining: 27.3s
# 515:	learn: 0.1486882	total: 29s	remaining: 27.2s
# 516:	learn: 0.1484317	total: 29.1s	remaining: 27.2s
# 517:	learn: 0.1483867	total: 29.1s	remaining: 27.1s
# 518:	learn: 0.1481903	total: 29.2s	remaining: 27s
# 519:	learn: 0.1481664	total: 29.2s	remaining: 27s
# 520:	learn: 0.1480768	total: 29.3s	remaining: 26.9s
# 521:	learn: 0.1480272	total: 29.3s	remaining: 26.9s
# 522:	learn: 0.1479765	total: 29.4s	remaining: 26.8s
# 523:	learn: 0.1479322	total: 29.4s	remaining: 26.7s
# 524:	learn: 0.1478997	total: 29.5s	remaining: 26.7s
# 525:	learn: 0.1477504	total: 29.5s	remaining: 26.6s
# 526:	learn: 0.1477114	total: 29.6s	remaining: 26.6s
# 527:	learn: 0.1476952	total: 29.6s	remaining: 26.5s
# 528:	learn: 0.1475659	total: 29.7s	remaining: 26.5s
# 529:	learn: 0.1475382	total: 29.8s	remaining: 26.4s
# 530:	learn: 0.1474850	total: 29.9s	remaining: 26.4s
# 531:	learn: 0.1474345	total: 30s	remaining: 26.4s
# 532:	learn: 0.1473666	total: 30.1s	remaining: 26.3s
# 533:	learn: 0.1473278	total: 30.1s	remaining: 26.3s
# 534:	learn: 0.1469258	total: 30.2s	remaining: 26.2s
# 535:	learn: 0.1469043	total: 30.2s	remaining: 26.2s
# 536:	learn: 0.1468366	total: 30.3s	remaining: 26.1s
# 537:	learn: 0.1467939	total: 30.3s	remaining: 26s
# 538:	learn: 0.1466774	total: 30.4s	remaining: 26s
# 539:	learn: 0.1466068	total: 30.4s	remaining: 25.9s
# 540:	learn: 0.1465402	total: 30.5s	remaining: 25.9s
# 541:	learn: 0.1465034	total: 30.5s	remaining: 25.8s
# 542:	learn: 0.1464793	total: 30.6s	remaining: 25.8s
# 543:	learn: 0.1464359	total: 30.7s	remaining: 25.7s
# 544:	learn: 0.1464064	total: 30.7s	remaining: 25.6s
# 545:	learn: 0.1463795	total: 30.8s	remaining: 25.6s
# 546:	learn: 0.1462060	total: 30.8s	remaining: 25.5s
# 547:	learn: 0.1461737	total: 30.9s	remaining: 25.5s
# 548:	learn: 0.1461076	total: 30.9s	remaining: 25.4s
# 549:	learn: 0.1460061	total: 31s	remaining: 25.4s
# 550:	learn: 0.1457043	total: 31.1s	remaining: 25.4s
# 551:	learn: 0.1456466	total: 31.2s	remaining: 25.3s
# 552:	learn: 0.1456055	total: 31.3s	remaining: 25.3s
# 553:	learn: 0.1455538	total: 31.4s	remaining: 25.3s
# 554:	learn: 0.1454491	total: 31.4s	remaining: 25.2s
# 555:	learn: 0.1453865	total: 31.5s	remaining: 25.1s
# 556:	learn: 0.1453460	total: 31.5s	remaining: 25.1s
# 557:	learn: 0.1453045	total: 31.6s	remaining: 25s
# 558:	learn: 0.1452559	total: 31.6s	remaining: 24.9s
# 559:	learn: 0.1452419	total: 31.7s	remaining: 24.9s
# 560:	learn: 0.1449823	total: 31.7s	remaining: 24.8s
# 561:	learn: 0.1449198	total: 31.8s	remaining: 24.8s
# 562:	learn: 0.1447617	total: 31.8s	remaining: 24.7s
# 563:	learn: 0.1447079	total: 31.9s	remaining: 24.7s
# 564:	learn: 0.1445999	total: 31.9s	remaining: 24.6s
# 565:	learn: 0.1445704	total: 32s	remaining: 24.5s
# 566:	learn: 0.1445028	total: 32.1s	remaining: 24.5s
# 567:	learn: 0.1444662	total: 32.1s	remaining: 24.4s
# 568:	learn: 0.1444337	total: 32.2s	remaining: 24.4s
# 569:	learn: 0.1443650	total: 32.2s	remaining: 24.3s
# 570:	learn: 0.1443041	total: 32.3s	remaining: 24.3s
# 571:	learn: 0.1442160	total: 32.3s	remaining: 24.2s
# 572:	learn: 0.1440198	total: 32.4s	remaining: 24.1s
# 573:	learn: 0.1439731	total: 32.4s	remaining: 24.1s
# 574:	learn: 0.1438827	total: 32.5s	remaining: 24s
# 575:	learn: 0.1437947	total: 32.5s	remaining: 23.9s
# 576:	learn: 0.1436463	total: 32.6s	remaining: 23.9s
# 577:	learn: 0.1434835	total: 32.7s	remaining: 23.8s
# 578:	learn: 0.1434669	total: 32.7s	remaining: 23.8s
# 579:	learn: 0.1434554	total: 32.8s	remaining: 23.7s
# 580:	learn: 0.1434376	total: 32.9s	remaining: 23.7s
# 581:	learn: 0.1434094	total: 32.9s	remaining: 23.6s
# 582:	learn: 0.1433732	total: 33s	remaining: 23.6s
# 583:	learn: 0.1432539	total: 33s	remaining: 23.5s
# 584:	learn: 0.1431936	total: 33.1s	remaining: 23.5s
# 585:	learn: 0.1431650	total: 33.2s	remaining: 23.4s
# 586:	learn: 0.1431108	total: 33.2s	remaining: 23.4s
# 587:	learn: 0.1430846	total: 33.3s	remaining: 23.3s
# 588:	learn: 0.1430342	total: 33.3s	remaining: 23.3s
# 589:	learn: 0.1429882	total: 33.4s	remaining: 23.2s
# 590:	learn: 0.1429468	total: 33.4s	remaining: 23.1s
# 591:	learn: 0.1429286	total: 33.5s	remaining: 23.1s
# 592:	learn: 0.1428787	total: 33.6s	remaining: 23s
# 593:	learn: 0.1426969	total: 33.6s	remaining: 23s
# 594:	learn: 0.1426753	total: 33.7s	remaining: 22.9s
# 595:	learn: 0.1425547	total: 33.7s	remaining: 22.8s
# 596:	learn: 0.1424859	total: 33.7s	remaining: 22.8s
# 597:	learn: 0.1424606	total: 33.8s	remaining: 22.7s
# 598:	learn: 0.1424476	total: 33.8s	remaining: 22.7s
# 599:	learn: 0.1423243	total: 33.9s	remaining: 22.6s
# 600:	learn: 0.1422949	total: 33.9s	remaining: 22.5s
# 601:	learn: 0.1422777	total: 34s	remaining: 22.5s
# 602:	learn: 0.1420150	total: 34s	remaining: 22.4s
# 603:	learn: 0.1419483	total: 34.1s	remaining: 22.3s
# 604:	learn: 0.1417670	total: 34.1s	remaining: 22.3s
# 605:	learn: 0.1417177	total: 34.2s	remaining: 22.2s
# 606:	learn: 0.1416860	total: 34.2s	remaining: 22.2s
# 607:	learn: 0.1416157	total: 34.3s	remaining: 22.1s
# 608:	learn: 0.1415282	total: 34.3s	remaining: 22s
# 609:	learn: 0.1415192	total: 34.4s	remaining: 22s
# 610:	learn: 0.1413983	total: 34.4s	remaining: 21.9s
# 611:	learn: 0.1413667	total: 34.5s	remaining: 21.9s
# 612:	learn: 0.1413116	total: 34.5s	remaining: 21.8s
# 613:	learn: 0.1412188	total: 34.6s	remaining: 21.7s
# 614:	learn: 0.1411266	total: 34.6s	remaining: 21.7s
# 615:	learn: 0.1410684	total: 34.7s	remaining: 21.6s
# 616:	learn: 0.1410220	total: 34.7s	remaining: 21.6s
# 617:	learn: 0.1408338	total: 34.8s	remaining: 21.5s
# 618:	learn: 0.1407451	total: 34.8s	remaining: 21.4s
# 619:	learn: 0.1406273	total: 34.9s	remaining: 21.4s
# 620:	learn: 0.1405581	total: 34.9s	remaining: 21.3s
# 621:	learn: 0.1405471	total: 35s	remaining: 21.3s
# 622:	learn: 0.1404727	total: 35s	remaining: 21.2s
# 623:	learn: 0.1404496	total: 35.1s	remaining: 21.1s
# 624:	learn: 0.1403961	total: 35.1s	remaining: 21.1s
# 625:	learn: 0.1403299	total: 35.2s	remaining: 21s
# 626:	learn: 0.1402021	total: 35.2s	remaining: 21s
# 627:	learn: 0.1401300	total: 35.3s	remaining: 20.9s
# 628:	learn: 0.1400906	total: 35.3s	remaining: 20.8s
# 629:	learn: 0.1400587	total: 35.4s	remaining: 20.8s
# 630:	learn: 0.1400289	total: 35.4s	remaining: 20.7s
# 631:	learn: 0.1399947	total: 35.5s	remaining: 20.6s
# 632:	learn: 0.1399425	total: 35.5s	remaining: 20.6s
# 633:	learn: 0.1398887	total: 35.6s	remaining: 20.5s
# 634:	learn: 0.1398363	total: 35.6s	remaining: 20.5s
# 635:	learn: 0.1398030	total: 35.7s	remaining: 20.4s
# 636:	learn: 0.1397602	total: 35.7s	remaining: 20.3s
# 637:	learn: 0.1397301	total: 35.8s	remaining: 20.3s
# 638:	learn: 0.1395370	total: 35.8s	remaining: 20.2s
# 639:	learn: 0.1395141	total: 35.9s	remaining: 20.2s
# 640:	learn: 0.1394771	total: 35.9s	remaining: 20.1s
# 641:	learn: 0.1394201	total: 36s	remaining: 20.1s
# 642:	learn: 0.1393603	total: 36s	remaining: 20s
# 643:	learn: 0.1392468	total: 36s	remaining: 19.9s
# 644:	learn: 0.1391548	total: 36.1s	remaining: 19.9s
# 645:	learn: 0.1391177	total: 36.1s	remaining: 19.8s
# 646:	learn: 0.1389424	total: 36.2s	remaining: 19.7s
# 647:	learn: 0.1388221	total: 36.2s	remaining: 19.7s
# 648:	learn: 0.1387718	total: 36.3s	remaining: 19.6s
# 649:	learn: 0.1386596	total: 36.3s	remaining: 19.6s
# 650:	learn: 0.1385665	total: 36.4s	remaining: 19.5s
# 651:	learn: 0.1385144	total: 36.4s	remaining: 19.4s
# 652:	learn: 0.1384783	total: 36.5s	remaining: 19.4s
# 653:	learn: 0.1384661	total: 36.5s	remaining: 19.3s
# 654:	learn: 0.1384348	total: 36.6s	remaining: 19.3s
# 655:	learn: 0.1383974	total: 36.6s	remaining: 19.2s
# 656:	learn: 0.1383454	total: 36.7s	remaining: 19.1s
# 657:	learn: 0.1383313	total: 36.7s	remaining: 19.1s
# 658:	learn: 0.1382973	total: 36.8s	remaining: 19s
# 659:	learn: 0.1382555	total: 36.8s	remaining: 19s
# 660:	learn: 0.1382420	total: 36.9s	remaining: 18.9s
# 661:	learn: 0.1381970	total: 36.9s	remaining: 18.8s
# 662:	learn: 0.1381043	total: 37s	remaining: 18.8s
# 663:	learn: 0.1380190	total: 37s	remaining: 18.7s
# 664:	learn: 0.1379032	total: 37.1s	remaining: 18.7s
# 665:	learn: 0.1378486	total: 37.1s	remaining: 18.6s
# 666:	learn: 0.1378381	total: 37.2s	remaining: 18.6s
# 667:	learn: 0.1378341	total: 37.2s	remaining: 18.5s
# 668:	learn: 0.1377793	total: 37.3s	remaining: 18.4s
# 669:	learn: 0.1377377	total: 37.3s	remaining: 18.4s
# 670:	learn: 0.1377309	total: 37.4s	remaining: 18.3s
# 671:	learn: 0.1376230	total: 37.4s	remaining: 18.3s
# 672:	learn: 0.1375968	total: 37.4s	remaining: 18.2s
# 673:	learn: 0.1375592	total: 37.5s	remaining: 18.1s
# 674:	learn: 0.1375390	total: 37.5s	remaining: 18.1s
# 675:	learn: 0.1374828	total: 37.6s	remaining: 18s
# 676:	learn: 0.1373747	total: 37.6s	remaining: 17.9s
# 677:	learn: 0.1373486	total: 37.7s	remaining: 17.9s
# 678:	learn: 0.1372445	total: 37.7s	remaining: 17.8s
# 679:	learn: 0.1372258	total: 37.8s	remaining: 17.8s
# 680:	learn: 0.1371718	total: 37.8s	remaining: 17.7s
# 681:	learn: 0.1371306	total: 37.9s	remaining: 17.7s
# 682:	learn: 0.1370758	total: 37.9s	remaining: 17.6s
# 683:	learn: 0.1370601	total: 38s	remaining: 17.5s
# 684:	learn: 0.1370353	total: 38s	remaining: 17.5s
# 685:	learn: 0.1369886	total: 38.1s	remaining: 17.4s
# 686:	learn: 0.1369445	total: 38.1s	remaining: 17.4s
# 687:	learn: 0.1368517	total: 38.2s	remaining: 17.3s
# 688:	learn: 0.1368013	total: 38.2s	remaining: 17.2s
# 689:	learn: 0.1367834	total: 38.3s	remaining: 17.2s
# 690:	learn: 0.1367600	total: 38.3s	remaining: 17.1s
# 691:	learn: 0.1367441	total: 38.4s	remaining: 17.1s
# 692:	learn: 0.1366077	total: 38.4s	remaining: 17s
# 693:	learn: 0.1365748	total: 38.5s	remaining: 17s
# 694:	learn: 0.1365310	total: 38.5s	remaining: 16.9s
# 695:	learn: 0.1364670	total: 38.6s	remaining: 16.8s
# 696:	learn: 0.1364242	total: 38.6s	remaining: 16.8s
# 697:	learn: 0.1363942	total: 38.7s	remaining: 16.7s
# 698:	learn: 0.1361433	total: 38.7s	remaining: 16.7s
# 699:	learn: 0.1361210	total: 38.7s	remaining: 16.6s
# 700:	learn: 0.1359862	total: 38.8s	remaining: 16.5s
# 701:	learn: 0.1359511	total: 38.8s	remaining: 16.5s
# 702:	learn: 0.1358542	total: 38.9s	remaining: 16.4s
# 703:	learn: 0.1358090	total: 38.9s	remaining: 16.4s
# 704:	learn: 0.1356527	total: 39s	remaining: 16.3s
# 705:	learn: 0.1356050	total: 39s	remaining: 16.3s
# 706:	learn: 0.1355641	total: 39.1s	remaining: 16.2s
# 707:	learn: 0.1355258	total: 39.1s	remaining: 16.1s
# 708:	learn: 0.1355097	total: 39.2s	remaining: 16.1s
# 709:	learn: 0.1354316	total: 39.2s	remaining: 16s
# 710:	learn: 0.1352944	total: 39.3s	remaining: 16s
# 711:	learn: 0.1352678	total: 39.3s	remaining: 15.9s
# 712:	learn: 0.1351248	total: 39.4s	remaining: 15.8s
# 713:	learn: 0.1350694	total: 39.4s	remaining: 15.8s
# 714:	learn: 0.1350057	total: 39.5s	remaining: 15.7s
# 715:	learn: 0.1349816	total: 39.5s	remaining: 15.7s
# 716:	learn: 0.1349771	total: 39.6s	remaining: 15.6s
# 717:	learn: 0.1349535	total: 39.6s	remaining: 15.6s
# 718:	learn: 0.1349297	total: 39.7s	remaining: 15.5s
# 719:	learn: 0.1349153	total: 39.7s	remaining: 15.4s
# 720:	learn: 0.1348983	total: 39.8s	remaining: 15.4s
# 721:	learn: 0.1348463	total: 39.8s	remaining: 15.3s
# 722:	learn: 0.1347923	total: 39.9s	remaining: 15.3s
# 723:	learn: 0.1347539	total: 39.9s	remaining: 15.2s
# 724:	learn: 0.1347443	total: 40s	remaining: 15.2s
# 725:	learn: 0.1346306	total: 40s	remaining: 15.1s
# 726:	learn: 0.1346203	total: 40s	remaining: 15s
# 727:	learn: 0.1345164	total: 40.1s	remaining: 15s
# 728:	learn: 0.1344016	total: 40.1s	remaining: 14.9s
# 729:	learn: 0.1343336	total: 40.2s	remaining: 14.9s
# 730:	learn: 0.1343187	total: 40.2s	remaining: 14.8s
# 731:	learn: 0.1342681	total: 40.3s	remaining: 14.7s
# 732:	learn: 0.1342483	total: 40.3s	remaining: 14.7s
# 733:	learn: 0.1342221	total: 40.4s	remaining: 14.6s
# 734:	learn: 0.1341676	total: 40.4s	remaining: 14.6s
# 735:	learn: 0.1341385	total: 40.5s	remaining: 14.5s
# 736:	learn: 0.1341097	total: 40.5s	remaining: 14.5s
# 737:	learn: 0.1340631	total: 40.6s	remaining: 14.4s
# 738:	learn: 0.1340432	total: 40.6s	remaining: 14.3s
# 739:	learn: 0.1339388	total: 40.7s	remaining: 14.3s
# 740:	learn: 0.1339003	total: 40.7s	remaining: 14.2s
# 741:	learn: 0.1338300	total: 40.8s	remaining: 14.2s
# 742:	learn: 0.1337985	total: 40.8s	remaining: 14.1s
# 743:	learn: 0.1337439	total: 40.9s	remaining: 14.1s
# 744:	learn: 0.1336716	total: 40.9s	remaining: 14s
# 745:	learn: 0.1336469	total: 41s	remaining: 13.9s
# 746:	learn: 0.1336095	total: 41s	remaining: 13.9s
# 747:	learn: 0.1335140	total: 41.1s	remaining: 13.8s
# 748:	learn: 0.1334714	total: 41.1s	remaining: 13.8s
# 749:	learn: 0.1334373	total: 41.2s	remaining: 13.7s
# 750:	learn: 0.1334244	total: 41.2s	remaining: 13.7s
# 751:	learn: 0.1334144	total: 41.3s	remaining: 13.6s
# 752:	learn: 0.1333782	total: 41.3s	remaining: 13.5s
# 753:	learn: 0.1333576	total: 41.4s	remaining: 13.5s
# 754:	learn: 0.1332681	total: 41.4s	remaining: 13.4s
# 755:	learn: 0.1332067	total: 41.4s	remaining: 13.4s
# 756:	learn: 0.1330822	total: 41.5s	remaining: 13.3s
# 757:	learn: 0.1330684	total: 41.5s	remaining: 13.3s
# 758:	learn: 0.1330207	total: 41.6s	remaining: 13.2s
# 759:	learn: 0.1330148	total: 41.6s	remaining: 13.1s
# 760:	learn: 0.1329732	total: 41.7s	remaining: 13.1s
# 761:	learn: 0.1329282	total: 41.7s	remaining: 13s
# 762:	learn: 0.1328737	total: 41.8s	remaining: 13s
# 763:	learn: 0.1327637	total: 41.8s	remaining: 12.9s
# 764:	learn: 0.1326981	total: 41.9s	remaining: 12.9s
# 765:	learn: 0.1326403	total: 41.9s	remaining: 12.8s
# 766:	learn: 0.1326159	total: 42s	remaining: 12.8s
# 767:	learn: 0.1325739	total: 42s	remaining: 12.7s
# 768:	learn: 0.1325217	total: 42.1s	remaining: 12.6s
# 769:	learn: 0.1324491	total: 42.1s	remaining: 12.6s
# 770:	learn: 0.1323980	total: 42.2s	remaining: 12.5s
# 771:	learn: 0.1323491	total: 42.2s	remaining: 12.5s
# 772:	learn: 0.1323045	total: 42.3s	remaining: 12.4s
# 773:	learn: 0.1322052	total: 42.3s	remaining: 12.4s
# 774:	learn: 0.1321837	total: 42.4s	remaining: 12.3s
# 775:	learn: 0.1321637	total: 42.4s	remaining: 12.2s
# 776:	learn: 0.1321502	total: 42.5s	remaining: 12.2s
# 777:	learn: 0.1321129	total: 42.5s	remaining: 12.1s
# 778:	learn: 0.1320844	total: 42.6s	remaining: 12.1s
# 779:	learn: 0.1320200	total: 42.6s	remaining: 12s
# 780:	learn: 0.1319771	total: 42.7s	remaining: 12s
# 781:	learn: 0.1319547	total: 42.7s	remaining: 11.9s
# 782:	learn: 0.1318731	total: 42.8s	remaining: 11.9s
# 783:	learn: 0.1318346	total: 42.8s	remaining: 11.8s
# 784:	learn: 0.1317809	total: 42.9s	remaining: 11.7s
# 785:	learn: 0.1316051	total: 42.9s	remaining: 11.7s
# 786:	learn: 0.1315052	total: 43s	remaining: 11.6s
# 787:	learn: 0.1314637	total: 43s	remaining: 11.6s
# 788:	learn: 0.1313855	total: 43.1s	remaining: 11.5s
# 789:	learn: 0.1313355	total: 43.1s	remaining: 11.5s
# 790:	learn: 0.1313181	total: 43.1s	remaining: 11.4s
# 791:	learn: 0.1312078	total: 43.2s	remaining: 11.3s
# 792:	learn: 0.1311851	total: 43.2s	remaining: 11.3s
# 793:	learn: 0.1311320	total: 43.3s	remaining: 11.2s
# 794:	learn: 0.1310604	total: 43.3s	remaining: 11.2s
# 795:	learn: 0.1310187	total: 43.4s	remaining: 11.1s
# 796:	learn: 0.1309546	total: 43.4s	remaining: 11.1s
# 797:	learn: 0.1309192	total: 43.5s	remaining: 11s
# 798:	learn: 0.1309072	total: 43.5s	remaining: 10.9s
# 799:	learn: 0.1308840	total: 43.6s	remaining: 10.9s
# 800:	learn: 0.1308588	total: 43.6s	remaining: 10.8s
# 801:	learn: 0.1308188	total: 43.7s	remaining: 10.8s
# 802:	learn: 0.1307952	total: 43.7s	remaining: 10.7s
# 803:	learn: 0.1307643	total: 43.8s	remaining: 10.7s
# 804:	learn: 0.1307022	total: 43.8s	remaining: 10.6s
# 805:	learn: 0.1306788	total: 43.8s	remaining: 10.6s
# 806:	learn: 0.1306052	total: 43.9s	remaining: 10.5s
# 807:	learn: 0.1305777	total: 43.9s	remaining: 10.4s
# 808:	learn: 0.1305287	total: 44s	remaining: 10.4s
# 809:	learn: 0.1304195	total: 44s	remaining: 10.3s
# 810:	learn: 0.1304085	total: 44.1s	remaining: 10.3s
# 811:	learn: 0.1303769	total: 44.1s	remaining: 10.2s
# 812:	learn: 0.1303110	total: 44.2s	remaining: 10.2s
# 813:	learn: 0.1302810	total: 44.2s	remaining: 10.1s
# 814:	learn: 0.1302167	total: 44.3s	remaining: 10.1s
# 815:	learn: 0.1302022	total: 44.3s	remaining: 9.99s
# 816:	learn: 0.1301560	total: 44.4s	remaining: 9.94s
# 817:	learn: 0.1300219	total: 44.4s	remaining: 9.88s
# 818:	learn: 0.1299937	total: 44.5s	remaining: 9.83s
# 819:	learn: 0.1299677	total: 44.5s	remaining: 9.77s
# 820:	learn: 0.1297925	total: 44.6s	remaining: 9.72s
# 821:	learn: 0.1297798	total: 44.6s	remaining: 9.66s
# 822:	learn: 0.1297369	total: 44.7s	remaining: 9.61s
# 823:	learn: 0.1296930	total: 44.7s	remaining: 9.55s
# 824:	learn: 0.1296605	total: 44.8s	remaining: 9.5s
# 825:	learn: 0.1295744	total: 44.8s	remaining: 9.44s
# 826:	learn: 0.1295118	total: 44.9s	remaining: 9.39s
# 827:	learn: 0.1294920	total: 44.9s	remaining: 9.33s
# 828:	learn: 0.1294644	total: 45s	remaining: 9.28s
# 829:	learn: 0.1294036	total: 45s	remaining: 9.22s
# 830:	learn: 0.1293581	total: 45.1s	remaining: 9.17s
# 831:	learn: 0.1293156	total: 45.1s	remaining: 9.11s
# 832:	learn: 0.1292858	total: 45.2s	remaining: 9.05s
# 833:	learn: 0.1292134	total: 45.2s	remaining: 9s
# 834:	learn: 0.1291317	total: 45.3s	remaining: 8.94s
# 835:	learn: 0.1291024	total: 45.3s	remaining: 8.89s
# 836:	learn: 0.1290702	total: 45.4s	remaining: 8.83s
# 837:	learn: 0.1290073	total: 45.4s	remaining: 8.78s
# 838:	learn: 0.1289456	total: 45.5s	remaining: 8.72s
# 839:	learn: 0.1289172	total: 45.5s	remaining: 8.67s
# 840:	learn: 0.1288734	total: 45.6s	remaining: 8.61s
# 841:	learn: 0.1288542	total: 45.6s	remaining: 8.56s
# 842:	learn: 0.1288294	total: 45.6s	remaining: 8.5s
# 843:	learn: 0.1288083	total: 45.7s	remaining: 8.45s
# 844:	learn: 0.1287571	total: 45.7s	remaining: 8.39s
# 845:	learn: 0.1287315	total: 45.8s	remaining: 8.34s
# 846:	learn: 0.1286738	total: 45.8s	remaining: 8.28s
# 847:	learn: 0.1286121	total: 45.9s	remaining: 8.22s
# 848:	learn: 0.1285823	total: 45.9s	remaining: 8.17s
# 849:	learn: 0.1285214	total: 46s	remaining: 8.11s
# 850:	learn: 0.1284875	total: 46s	remaining: 8.06s
# 851:	learn: 0.1284655	total: 46.1s	remaining: 8s
# 852:	learn: 0.1284269	total: 46.1s	remaining: 7.95s
# 853:	learn: 0.1283973	total: 46.2s	remaining: 7.89s
# 854:	learn: 0.1283715	total: 46.2s	remaining: 7.84s
# 855:	learn: 0.1283304	total: 46.3s	remaining: 7.78s
# 856:	learn: 0.1283139	total: 46.3s	remaining: 7.72s
# 857:	learn: 0.1282336	total: 46.3s	remaining: 7.67s
# 858:	learn: 0.1281875	total: 46.4s	remaining: 7.61s
# 859:	learn: 0.1281735	total: 46.4s	remaining: 7.56s
# 860:	learn: 0.1281256	total: 46.5s	remaining: 7.5s
# 861:	learn: 0.1281182	total: 46.5s	remaining: 7.45s
# 862:	learn: 0.1281124	total: 46.6s	remaining: 7.4s
# 863:	learn: 0.1280869	total: 46.6s	remaining: 7.34s
# 864:	learn: 0.1280062	total: 46.7s	remaining: 7.29s
# 865:	learn: 0.1279807	total: 46.7s	remaining: 7.23s
# 866:	learn: 0.1279544	total: 46.8s	remaining: 7.18s
# 867:	learn: 0.1279312	total: 46.8s	remaining: 7.12s
# 868:	learn: 0.1278416	total: 46.9s	remaining: 7.07s
# 869:	learn: 0.1278321	total: 46.9s	remaining: 7.01s
# 870:	learn: 0.1277975	total: 47s	remaining: 6.96s
# 871:	learn: 0.1277861	total: 47s	remaining: 6.9s
# 872:	learn: 0.1277707	total: 47.1s	remaining: 6.85s
# 873:	learn: 0.1277340	total: 47.1s	remaining: 6.79s
# 874:	learn: 0.1276818	total: 47.2s	remaining: 6.74s
# 875:	learn: 0.1276571	total: 47.2s	remaining: 6.68s
# 876:	learn: 0.1276289	total: 47.3s	remaining: 6.63s
# 877:	learn: 0.1276105	total: 47.3s	remaining: 6.57s
# 878:	learn: 0.1275948	total: 47.4s	remaining: 6.52s
# 879:	learn: 0.1275672	total: 47.4s	remaining: 6.46s
# 880:	learn: 0.1275238	total: 47.5s	remaining: 6.41s
# 881:	learn: 0.1274832	total: 47.5s	remaining: 6.35s
# 882:	learn: 0.1274409	total: 47.5s	remaining: 6.3s
# 883:	learn: 0.1274159	total: 47.6s	remaining: 6.25s
# 884:	learn: 0.1274010	total: 47.7s	remaining: 6.19s
# 885:	learn: 0.1273801	total: 47.7s	remaining: 6.14s
# 886:	learn: 0.1273554	total: 47.8s	remaining: 6.08s
# 887:	learn: 0.1273430	total: 47.8s	remaining: 6.03s
# 888:	learn: 0.1273189	total: 47.9s	remaining: 5.97s
# 889:	learn: 0.1272733	total: 47.9s	remaining: 5.92s
# 890:	learn: 0.1272565	total: 48s	remaining: 5.87s
# 891:	learn: 0.1271807	total: 48s	remaining: 5.81s
# 892:	learn: 0.1270924	total: 48.1s	remaining: 5.76s
# 893:	learn: 0.1270058	total: 48.1s	remaining: 5.7s
# 894:	learn: 0.1269633	total: 48.2s	remaining: 5.65s
# 895:	learn: 0.1269340	total: 48.2s	remaining: 5.59s
# 896:	learn: 0.1269179	total: 48.2s	remaining: 5.54s
# 897:	learn: 0.1268963	total: 48.3s	remaining: 5.49s
# 898:	learn: 0.1268016	total: 48.3s	remaining: 5.43s
# 899:	learn: 0.1267873	total: 48.4s	remaining: 5.38s
# 900:	learn: 0.1267320	total: 48.4s	remaining: 5.32s
# 901:	learn: 0.1266910	total: 48.5s	remaining: 5.27s
# 902:	learn: 0.1266761	total: 48.5s	remaining: 5.21s
# 903:	learn: 0.1266609	total: 48.6s	remaining: 5.16s
# 904:	learn: 0.1266516	total: 48.6s	remaining: 5.11s
# 905:	learn: 0.1266137	total: 48.7s	remaining: 5.05s
# 906:	learn: 0.1265709	total: 48.7s	remaining: 5s
# 907:	learn: 0.1265360	total: 48.8s	remaining: 4.94s
# 908:	learn: 0.1265152	total: 48.8s	remaining: 4.89s
# 909:	learn: 0.1264729	total: 48.9s	remaining: 4.83s
# 910:	learn: 0.1264619	total: 48.9s	remaining: 4.78s
# 911:	learn: 0.1264229	total: 49s	remaining: 4.72s
# 912:	learn: 0.1263646	total: 49s	remaining: 4.67s
# 913:	learn: 0.1263420	total: 49.1s	remaining: 4.62s
# 914:	learn: 0.1263226	total: 49.1s	remaining: 4.56s
# 915:	learn: 0.1262262	total: 49.2s	remaining: 4.51s
# 916:	learn: 0.1262073	total: 49.2s	remaining: 4.46s
# 917:	learn: 0.1261757	total: 49.3s	remaining: 4.4s
# 918:	learn: 0.1261444	total: 49.3s	remaining: 4.35s
# 919:	learn: 0.1261239	total: 49.4s	remaining: 4.29s
# 920:	learn: 0.1261125	total: 49.4s	remaining: 4.24s
# 921:	learn: 0.1261003	total: 49.5s	remaining: 4.18s
# 922:	learn: 0.1260786	total: 49.5s	remaining: 4.13s
# 923:	learn: 0.1260286	total: 49.5s	remaining: 4.08s
# 924:	learn: 0.1260026	total: 49.6s	remaining: 4.02s
# 925:	learn: 0.1259289	total: 49.6s	remaining: 3.97s
# 926:	learn: 0.1259110	total: 49.7s	remaining: 3.91s
# 927:	learn: 0.1258917	total: 49.7s	remaining: 3.86s
# 928:	learn: 0.1258710	total: 49.8s	remaining: 3.8s
# 929:	learn: 0.1258557	total: 49.8s	remaining: 3.75s
# 930:	learn: 0.1258300	total: 49.9s	remaining: 3.7s
# 931:	learn: 0.1258155	total: 49.9s	remaining: 3.64s
# 932:	learn: 0.1258034	total: 50s	remaining: 3.59s
# 933:	learn: 0.1256967	total: 50s	remaining: 3.54s
# 934:	learn: 0.1256674	total: 50.1s	remaining: 3.48s
# 935:	learn: 0.1256450	total: 50.1s	remaining: 3.43s
# 936:	learn: 0.1256239	total: 50.2s	remaining: 3.37s
# 937:	learn: 0.1255875	total: 50.2s	remaining: 3.32s
# 938:	learn: 0.1255273	total: 50.3s	remaining: 3.27s
# 939:	learn: 0.1255173	total: 50.3s	remaining: 3.21s
# 940:	learn: 0.1254919	total: 50.4s	remaining: 3.16s
# 941:	learn: 0.1254688	total: 50.4s	remaining: 3.1s
# 942:	learn: 0.1254500	total: 50.5s	remaining: 3.05s
# 943:	learn: 0.1254219	total: 50.5s	remaining: 3s
# 944:	learn: 0.1253895	total: 50.6s	remaining: 2.94s
# 945:	learn: 0.1253729	total: 50.6s	remaining: 2.89s
# 946:	learn: 0.1253332	total: 50.7s	remaining: 2.83s
# 947:	learn: 0.1253225	total: 50.7s	remaining: 2.78s
# 948:	learn: 0.1252993	total: 50.7s	remaining: 2.73s
# 949:	learn: 0.1252491	total: 50.8s	remaining: 2.67s
# 950:	learn: 0.1252035	total: 50.8s	remaining: 2.62s
# 951:	learn: 0.1251684	total: 50.9s	remaining: 2.57s
# 952:	learn: 0.1251540	total: 50.9s	remaining: 2.51s
# 953:	learn: 0.1250946	total: 51s	remaining: 2.46s
# 954:	learn: 0.1250746	total: 51s	remaining: 2.4s
# 955:	learn: 0.1250516	total: 51.1s	remaining: 2.35s
# 956:	learn: 0.1250435	total: 51.1s	remaining: 2.3s
# 957:	learn: 0.1250267	total: 51.2s	remaining: 2.24s
# 958:	learn: 0.1250002	total: 51.2s	remaining: 2.19s
# 959:	learn: 0.1249826	total: 51.3s	remaining: 2.14s
# 960:	learn: 0.1249430	total: 51.3s	remaining: 2.08s
# 961:	learn: 0.1248599	total: 51.4s	remaining: 2.03s
# 962:	learn: 0.1248397	total: 51.4s	remaining: 1.98s
# 963:	learn: 0.1248258	total: 51.5s	remaining: 1.92s
# 964:	learn: 0.1248196	total: 51.5s	remaining: 1.87s
# 965:	learn: 0.1248097	total: 51.6s	remaining: 1.81s
# 966:	learn: 0.1247904	total: 51.6s	remaining: 1.76s
# 967:	learn: 0.1247434	total: 51.7s	remaining: 1.71s
# 968:	learn: 0.1247334	total: 51.7s	remaining: 1.65s
# 969:	learn: 0.1247077	total: 51.8s	remaining: 1.6s
# 970:	learn: 0.1246890	total: 51.8s	remaining: 1.55s
# 971:	learn: 0.1246339	total: 51.9s	remaining: 1.49s
# 972:	learn: 0.1245426	total: 51.9s	remaining: 1.44s
# 973:	learn: 0.1244996	total: 52s	remaining: 1.39s
# 974:	learn: 0.1244844	total: 52s	remaining: 1.33s
# 975:	learn: 0.1244612	total: 52.1s	remaining: 1.28s
# 976:	learn: 0.1244489	total: 52.1s	remaining: 1.23s
# 977:	learn: 0.1244215	total: 52.2s	remaining: 1.17s
# 978:	learn: 0.1244138	total: 52.2s	remaining: 1.12s
# 979:	learn: 0.1243771	total: 52.3s	remaining: 1.07s
# 980:	learn: 0.1243643	total: 52.3s	remaining: 1.01s
# 981:	learn: 0.1243399	total: 52.4s	remaining: 960ms
# 982:	learn: 0.1242613	total: 52.4s	remaining: 906ms
# 983:	learn: 0.1242397	total: 52.5s	remaining: 853ms
# 984:	learn: 0.1242384	total: 52.5s	remaining: 800ms
# 985:	learn: 0.1242045	total: 52.5s	remaining: 746ms
# 986:	learn: 0.1240643	total: 52.6s	remaining: 693ms
# 987:	learn: 0.1240485	total: 52.6s	remaining: 639ms
# 988:	learn: 0.1240271	total: 52.7s	remaining: 586ms
# 989:	learn: 0.1240137	total: 52.7s	remaining: 533ms
# 990:	learn: 0.1239608	total: 52.8s	remaining: 479ms
# 991:	learn: 0.1239267	total: 52.8s	remaining: 426ms
# 992:	learn: 0.1239055	total: 52.9s	remaining: 373ms
# 993:	learn: 0.1239013	total: 53s	remaining: 320ms
# 994:	learn: 0.1238712	total: 53s	remaining: 266ms
# 995:	learn: 0.1238561	total: 53.1s	remaining: 213ms
# 996:	learn: 0.1238396	total: 53.1s	remaining: 160ms
# 997:	learn: 0.1238114	total: 53.2s	remaining: 107ms
# 998:	learn: 0.1237771	total: 53.2s	remaining: 53.3ms
# 999:	learn: 0.1237723	total: 53.3s	remaining: 0us
# Pipeline(steps=[('model_cast',
#                  <catboost.core.CatBoostRegressor object at 0x000001FAA37C7A90>)])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error ,mean_squared_log_error
from sklearn.metrics import r2_score

y_predict = pipeline_castboost.predict(X_test)

print(r2_score(Y_test, y_predict))
print(mean_squared_log_error(Y_test, y_predict))
print(mean_absolute_percentage_error(Y_test, y_predict))
# Out:
# 0.22323370258365827
# 0.09329096492247681
# 0.17645928714925696

# %%
from sklearn.ensemble import RandomForestRegressor

real_pipe = Pipeline([
    ('scaler', StandardScaler())])

cat_pipe = Pipeline([
    ('ohe', OneHotEncoder(handle_unknown='ignore',sparse=False))
])

preprocess_pipe = ColumnTransformer(transformers=[
    ('real_cols', real_pipe, REAL_COLS),
    ('cat_cols', cat_pipe, CAT_COLS),
    ('cat_bost_cols', ce.CountEncoder(), CAT_COLS), ##for work with cat_features
]
)

model_ltb = RandomForestRegressor()

model_pipe = Pipeline([
    ('preprocess', preprocess_pipe),
    ('model', model_ltb)
]
)

pipline_ltb = model_pipe
pipline_ltb.fit(X_train, Y_train)
# Out:
# c:\Users\dsfs-\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\pipeline.py:382: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('real_cols',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['MSSubClass', 'OverallQual',
#                                                    'OverallCond', 'LotFrontage',
#                                                    'LotArea', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF', 'GrLivArea',
#                                                    'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBat...
#                                                    'LandContour', 'Utilities',
#                                                    'LotConfig', 'LandSlope',
#                                                    'Neighborhood', 'Condition1',
#                                                    'Condition2', 'BldgType',
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('model', RandomForestRegressor())])

# %%
y_predict = pipline_ltb.predict(X_test)

print(r2_score(Y_test, y_predict))
print(mean_squared_log_error(Y_test, y_predict))
print(mean_absolute_percentage_error(Y_test, y_predict))
# Out:
# 0.8512954222995871
# 0.023178064153545997
# 0.11025103242494004

# %%
# from joblib import dump, load
# path_to_model = '../models/'
# dump(pipeline_castboost, os.path.join(path_to_model, 'pipeline_castboost.joblib')) 
# dump(pipline_ltb, os.path.join(path_to_model, 'pipline_ltb.joblib'))

# %% [markdown]
# ## Inference

# %%
# #processed_data_path = '../data/processed/'
# #path_to_model = '../models/'
# test = pd.read_pickle(os.path.join(processed_data_path, 'test.pkl'))
# model_1  = load(os.path.join(path_to_model, 'pipeline_castboost.joblib')) 
# model_2 = load(os.path.join(path_to_model, 'pipline_ltb.joblib'))

# %%
y_pred_1  = model_1.predict(test)
print(y_pred_1)
y_pred_2  = model_2.predict(test)
print(y_pred_2)
